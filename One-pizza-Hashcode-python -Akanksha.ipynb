# %% [markdown]
# importing pandas and numpy libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# creating dataframe and reading csv file

# %%
df=pd.read_csv("e_elaborate.in.txt")
df
# Out:
#                                                    4986
# 0     5 ingredient9922 ingredient3341 ingredient7670...
# 1                                      1 ingredient4654
# 2     5 ingredient2920 ingredient1643 ingredient5580...
# 3                       2 ingredient5259 ingredient9496
# 4     4 ingredient2857 ingredient9130 ingredient4932...
# ...                                                 ...
# 9967  5 ingredient1508 ingredient233 ingredient3435 ...
# 9968                                   1 ingredient6507
# 9969                                   1 ingredient4160
# 9970     3 ingredient6049 ingredient7794 ingredient3649
# 9971                                    1 ingredient172
#
# [9972 rows x 1 columns]

# %% [markdown]
# seperated even number lines into new dataframe(df2)---(even number indexed lines contains liked ingredients)

# %%
df2 = df.iloc[df.index%2==0]
df2.columns = ["like"]
df2.index = np.arange(len(df2))
df2["no_of_like"] = df2["like"].apply(lambda x : int(x.split(" ")[0]))
df2.head()
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   after removing the cwd from sys.path.
#                                                 like  no_of_like
# 0  5 ingredient9922 ingredient3341 ingredient7670...           5
# 1  5 ingredient2920 ingredient1643 ingredient5580...           5
# 2  4 ingredient2857 ingredient9130 ingredient4932...           4
# 3  5 ingredient8806 ingredient5320 ingredient569 ...           5
# 4                     2 ingredient697 ingredient8002           2

# %% [markdown]
# seperated odd number lines into new dataframe(df3)-- (odd indexes contains disliked ingredients)

# %%
df3 = df.copy()
df3 = df3.iloc[df.index%2==1]
df3.columns = ["dislike"]
df3.index = np.arange(len(df3))
df3["no_of_dislike"] = df3["dislike"].apply(lambda x : int(x.split(" ")[0]) )
df3.head()
# Out:
#                            dislike  no_of_dislike
# 0                 1 ingredient4654              1
# 1  2 ingredient5259 ingredient9496              2
# 2  2 ingredient2177 ingredient7332              2
# 3                 1 ingredient6321              1
# 4  2 ingredient4951 ingredient8544              2

# %% [markdown]
# merged df2 and df3

# %%
df4 = pd.concat([df2,df3],axis = 1)
df4.head()
# Out:
#                                                 like  ...  no_of_dislike
# 0  5 ingredient9922 ingredient3341 ingredient7670...  ...              1
# 1  5 ingredient2920 ingredient1643 ingredient5580...  ...              2
# 2  4 ingredient2857 ingredient9130 ingredient4932...  ...              2
# 3  5 ingredient8806 ingredient5320 ingredient569 ...  ...              1
# 4                     2 ingredient697 ingredient8002  ...              2
#
# [5 rows x 4 columns]

# %% [markdown]
# droped those rows which has dislike number greater or equals to 3

# %%
indexNames = df4[df4['no_of_dislike'] >= 3].index
df4 = df4.drop(indexNames)
df4.head()
# Out:
#                                                 like  ...  no_of_dislike
# 0  5 ingredient9922 ingredient3341 ingredient7670...  ...              1
# 1  5 ingredient2920 ingredient1643 ingredient5580...  ...              2
# 2  4 ingredient2857 ingredient9130 ingredient4932...  ...              2
# 3  5 ingredient8806 ingredient5320 ingredient569 ...  ...              1
# 4                     2 ingredient697 ingredient8002  ...              2
#
# [5 rows x 4 columns]

# %% [markdown]
# created new datafarame df5 with only liked ingredients

# %%
df5 = df4.drop(["dislike","no_of_dislike","no_of_like"],axis = 1)
df5.head()
# Out:
#                                                 like
# 0  5 ingredient9922 ingredient3341 ingredient7670...
# 1  5 ingredient2920 ingredient1643 ingredient5580...
# 2  4 ingredient2857 ingredient9130 ingredient4932...
# 3  5 ingredient8806 ingredient5320 ingredient569 ...
# 4                     2 ingredient697 ingredient8002

# %% [markdown]
# created new dataframe df6 with only disliked ingredients

# %%
df6 = df4.drop(["like","no_of_like","no_of_dislike"],axis=1)
df6.head()
# Out:
#                            dislike
# 0                 1 ingredient4654
# 1  2 ingredient5259 ingredient9496
# 2  2 ingredient2177 ingredient7332
# 3                 1 ingredient6321
# 4  2 ingredient4951 ingredient8544

# %% [markdown]
# seperated all liked ingredients into separate columns

# %%
for n in range(1,6):
  df5["like"+str(n)] = df5["like"].apply(lambda x : x.split(" ")[n] if len(x.split())>n else 0)

# %%
df5 = df5.drop(["like"],axis=1)
df5.head()
# Out:
#             like1           like2  ...           like4           like5
# 0  ingredient9922  ingredient3341  ...  ingredient7324  ingredient9885
# 1  ingredient2920  ingredient1643  ...  ingredient4239  ingredient7087
# 2  ingredient2857  ingredient9130  ...   ingredient664               0
# 3  ingredient8806  ingredient5320  ...  ingredient3724   ingredient656
# 4   ingredient697  ingredient8002  ...               0               0
#
# [5 rows x 5 columns]

# %% [markdown]
# unstack the dataframe df5

# %%
df5 = df5.unstack()
df5.head()
# Out:
# like1  0    ingredient9922
#        1    ingredient2920
#        2    ingredient2857
#        3    ingredient8806
#        4     ingredient697
# dtype: object

# %% [markdown]
# counted how many times particular ingredient comes in df5

# %%
df5 = df5.value_counts()
df5.head()
# Out:
# 0                 5084
# ingredient8011       6
# ingredient8029       5
# ingredient2611       5
# ingredient4042       5
# dtype: int64

# %%
df5 = df5.to_frame()
df5.head()
# Out:
#                    0
# 0               5084
# ingredient8011     6
# ingredient8029     5
# ingredient2611     5
# ingredient4042     5

# %%
df5 = df5.iloc[1: , :]
df5.head()
# Out:
#                 0
# ingredient8011  6
# ingredient8029  5
# ingredient2611  5
# ingredient4042  5
# ingredient9089  5

# %% [markdown]
# final dataset representing like score of all ingredients

# %%
df5 = df5.set_axis(['like_score'], axis=1, inplace=False)
df5.head()
# Out:
#                 like_score
# ingredient8011           6
# ingredient8029           5
# ingredient2611           5
# ingredient4042           5
# ingredient9089           5

# %% [markdown]
# separated disliked ingredient into separate columns

# %%
for n in range(1,3):
  df6["dislike"+str(n)] = df6["dislike"].apply(lambda x : x.split(" ")[n] if len(x.split())>n else 0)
df6 = df6.drop(["dislike"],axis = 1)
df6.head()
# Out:
#          dislike1        dislike2
# 0  ingredient4654               0
# 1  ingredient5259  ingredient9496
# 2  ingredient2177  ingredient7332
# 3  ingredient6321               0
# 4  ingredient4951  ingredient8544

# %%
df6 = df6.unstack()
df6.head()
# Out:
# dislike1  0    ingredient4654
#           1    ingredient5259
#           2    ingredient2177
#           3    ingredient6321
#           4    ingredient4951
# dtype: object

# %%
df6 = df6.value_counts()
df6.head()
# Out:
# 0                 2533
# ingredient9156       3
# ingredient7017       3
# ingredient1672       3
# ingredient5411       3
# dtype: int64

# %%
df6 = df6.to_frame()
df6 = df6.set_axis(['dislike_score'], axis=1, inplace=False)
df6 = df6.iloc[1: , :]
df6.head()
# Out:
#                 dislike_score
# ingredient9156              3
# ingredient7017              3
# ingredient1672              3
# ingredient5411              3
# ingredient2271              3

# %% [markdown]
# final dataset representing total dislike score for all ingredients
#
# merged dataframe of like score and dislike score

# %%
df7 = pd.concat([df5,df6],axis=1)
df7.head()
# Out:
#                 like_score  dislike_score
# ingredient8011         6.0            NaN
# ingredient8029         5.0            1.0
# ingredient2611         5.0            NaN
# ingredient4042         5.0            NaN
# ingredient9089         5.0            NaN

# %% [markdown]
# replaced null values to 0

# %%
df7 = df7.fillna(0)
df7.head()
# Out:
#                 like_score  dislike_score
# ingredient8011         6.0            0.0
# ingredient8029         5.0            1.0
# ingredient2611         5.0            0.0
# ingredient4042         5.0            0.0
# ingredient9089         5.0            0.0

# %% [markdown]
# added extra column representing names of ingredients

# %%
df7["Ingredient"] = df7.index
df7.head()
# Out:
#                 like_score  dislike_score      Ingredient
# ingredient8011         6.0            0.0  ingredient8011
# ingredient8029         5.0            1.0  ingredient8029
# ingredient2611         5.0            0.0  ingredient2611
# ingredient4042         5.0            0.0  ingredient4042
# ingredient9089         5.0            0.0  ingredient9089

# %% [markdown]
# created list with ingredients which has like score greater then dislike score

# %%
Ingre_list = []
for n in range(1,len(df7)):
  if df7.iloc[n,0] >= df7.iloc[n,1]:
    Ingre_list.append(df7.iloc[n,2])

# %%
len(Ingre_list)
# Out:
# 5761

# %% [markdown]
# hash code submission file created

# %%
str1 = ""
for i in Ingre_list:
  str1 =  str1+" "+i 

ans=  str(len(Ingre_list))+" "+str1    
newfile = open("Ans.txt","w+")
newfile.write(ans)
# Out:
# 85808

# %% [markdown]
# # Score Simulator

# %%
import linecache

input_filename = "e_elaborate.in.txt"
output_filename="Ans.txt" 


pl = int(linecache.getline(input_filename, 1))
with open(input_filename,'r') as f:  
  list_indi = [[0 for a in range(2)] for b in range(pl)] 
  def find_ingerdiants(list_indi):
    a=0
    for i in f:      
      a+=1
      if len(i)>2:
        k = i.split()
        if (a%2==0):
          k.pop(0)          
          list_indi[(a//2)-1][0]=k          
        else:
          k.pop(0)  
          list_indi[(a//2)-1][1]=k          
           
  find_ingerdiants(list_indi)

input_file = open(output_filename,"r")
lst = input_file.read().split()
lst.pop(0)

customer=0
for i in range(0,pl):
  a=0
  
  if list_indi[i][1] != 0:

    for j in range(0,len(list_indi[i][1])):
      if list_indi[i][1][j] in lst:
        a+=1
    if a>0:
      continue  
  if (set(list_indi[i][0]).issubset(set(lst))):
    customer+=1
    
print(customer)
# Out:
# 1425
